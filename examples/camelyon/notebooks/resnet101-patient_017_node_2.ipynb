# %%
import "fs"
import "camelyon"

# %%
patient := new Input {
    file_name: "patient_017_node_2",
    imagenet_weights: "resnet101_weights_tf.h5",
    model_weights: "tumor_classifier.h5",
    interpret: true,
    n_samples: 5
}

model := new Model {
    type: "resnet101",
    loss: "binary_crossentrophy",
    activation: "sigmoid",
    lr: "1e-4",
    decay: "1e-6",
    momentum: 0.9,
    nesterov: true,
    batch_size: 32,
    epochs: 15,
    verbose: 1
}

output_dir := new_directory
settings := new Settings {
    training_centres: "0,1,2,3",
    slide_level: 7,
    patch_size: 224,
    n_samples: 500,
    output_dir: output_dir
}

# %%
result := heatmap_of patient with model and settings

# %%
//!display result.heatmap

# %%
//!display result.heatmap_interpolated

# %%
result.elapsed_time

# %%
result.n_model

# %%
result.n_patches

# %%
//!display result.interpretability[0]

# %%
//!display result.interpretability[1]

# %%
//!display result.interpretability[2]

# %%
//!display result.interpretability[3]

# %%
//!display result.interpretability[4]

# %%
//!display result.logs
# Out:
# /usr/local/lib/python2.7/dist-packages/skimage/viewer/__init__.py:6: UserWarning: Viewer requires Qt
#   warn('Viewer requires Qt')
# Using TensorFlow backend.
# WARNING:tensorflow:From DHeatmap.py:114: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From DHeatmap.py:117: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-11-23 12:18:39.416654: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2020-11-23 12:18:39.424278: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2020-11-23 12:18:40.202999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-23 12:18:40.204774: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55649d4043b0 executing computations on platform CUDA. Devices:
# 2020-11-23 12:18:40.204867: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-11-23 12:18:40.220650: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2095074999 Hz
# 2020-11-23 12:18:40.221219: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55649d15cd10 executing computations on platform Host. Devices:
# 2020-11-23 12:18:40.221287: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2020-11-23 12:18:40.222078: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-23 12:18:40.224609: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:06.0
# 2020-11-23 12:18:40.227036: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2020-11-23 12:18:40.265290: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2020-11-23 12:18:40.285058: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2020-11-23 12:18:40.292012: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2020-11-23 12:18:40.338816: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2020-11-23 12:18:40.367356: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2020-11-23 12:18:40.439384: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2020-11-23 12:18:40.439719: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-23 12:18:40.441358: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-23 12:18:40.442853: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2020-11-23 12:18:40.443338: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2020-11-23 12:18:40.446610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-23 12:18:40.446649: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2020-11-23 12:18:40.446681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2020-11-23 12:18:40.447175: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-23 12:18:40.448654: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-23 12:18:40.450120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:06.0, compute capability: 7.5)
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:239: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:1801: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3661: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3665: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/optimizers.py:757: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/nn_impl.py:180: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# {'loss': 'binary_crossentrophy', 'verbose': 1, 'decay': 1e-06, 'nesterov': 'true', 'activation': 'sigmoid', 'batch_size': 32, 'epochs': 15, 'lr': 0.0001, 'model_type': 'resnet101', 'momentum': 0.9}
# interpreting network
# patient_017_node_2
# centre_0
# file name : /root/snedtn/camelyon17/working_subset/centre_0/patient_017_node_2.tif
#
# Whole Slide dimensions (with, heigth):(94968, 210579)
#
# slide.level_count-1 dimensions (width,heigth):(741, 1645)
#
# [1. 3. 1. ... 2. 1. 1.]
# Otsu threshold:  183.337890625
# [functions][data_preprocessing] NEW PREPROCESS FUNCTION
# [14381]
# Distributing inference over 4 model copies
# Instantiating model n.  0
# Loading weights...
# Adding model to available models.
# Instantiating model n.  1
# Loading weights...
# Adding model to available models.
# Instantiating model n.  2
# Loading weights...
# Adding model to available models.
# Instantiating model n.  3
# Loading weights...
# Adding model to available models.
# Heatmap dimensions:  741 1645
# 2020-11-23 12:21:30.410876: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2020-11-23 12:21:31.054981: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 0 5 0.910427 True
# 1 5 0.8952695 True
# 2 5 0.90681416 True
# 3 5 0.8239268 True
# 4 5 0.89354396 True
# Number of patches analysed:  43849.0
# Elapsed time:  1440.04347897
